# %% [markdown]
# # Distance and duration request using ORS

# %% [markdown]
# This notebook is an example for using different Openrouteservice tools. To get ready all needed packages were imported.

# %%
# %%bash
# git add ORS/use_cases/openrouteservice-examples/python/Kindergarten_SanFrancisco.ipynb
# Out:
# fatal: pathspec 'python/Kindergarten_SanFrancisco.ipynb' did not match any files

# %%
import folium
from folium import FeatureGroup, LayerControl, Map, Marker

from shapely import wkt, geometry
from shapely.geometry import shape

from pprint import pprint

import json

from openrouteservice import client, places, geocoding
from openrouteservice.directions import directions
from openrouteservice.isochrones import isochrones
from openrouteservice.places import places

# %% [markdown]
# We have just moved to San Francisco and are looking for the perfect location to get a new home. In a 15 minute walking radius there should be a kindergarten, a supertmarket and a post office.

# %%
api_key = '58d904a497c67e00015b45fc2a6b6872037d44119582ef40cdf264c4'
clnt = client.Client(key=api_key)

# %% [markdown]
# # isochrones

# %% [markdown]
# There are three different suggested locations for our new home. Let's visualize them and the 15 minute walking radius on a map:

# %%
map1 = folium.Map(tiles='Stamen Toner', location=([37.738684, -122.450523]), zoom_start=12) 

location_coords = {'first': [-122.430954, 37.792965], 'second': [-122.501636, 37.748653], 'third': [-122.446629, 37.736928]}

# Request of isochrones with 15 minute footwalk.
polygon_borders = []
for border_coords in location_coords:
    isochrone_request = isochrones(client=clnt, locations=location_coords[border_coords], profile='foot-walking', intervals=[900], segments=900)
    folium.GeoJson(isochrone_request).add_to(map1)
    polygon_borders.append(isochrone_request)
for house_coords in location_coords:
    location_coords[house_coords][0], location_coords[house_coords][1] = location_coords[house_coords][1], location_coords[house_coords][0]
    folium.Marker(location_coords[house_coords], icon=folium.Icon(color='lightgray',icon_color='#cc0000', icon='home', prefix='fa'), popup='Location suggestion').add_to(map1)
        
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # places

# %% [markdown]
# Now let's have a look how many kindergarten, supermarket and post offices there are in each walking radius.

# %%
# Request of wished places via individual filter category id.
all_kindergarten = []
for kindergarten_request in polygon_borders:
    all_kindergarten += [clnt.places(request='pois', geojson=kindergarten_request['features'][0]['geometry'], filter_category_ids=[153], sortby='distance')]
        
all_supermarket = []
for supermarket_request in polygon_borders:
    all_supermarket += [clnt.places(request='pois', geojson=supermarket_request['features'][0]['geometry'], filter_category_ids=[518], sortby='distance')]

all_post = []
for post_request in polygon_borders:
    all_post += [clnt.places(request='pois', geojson=post_request['features'][0]['geometry'], filter_category_ids=[370], sortby='distance')]

print("Amount of kindergarten in the first, second and third suggested area: ", [len(kindergarten_amount['features']) for kindergarten_amount in all_kindergarten])
print("Amount of supermarket in the first, second and third suggested area: ", [len(supermarket_amount['features']) for supermarket_amount in all_supermarket])
print("Amount of post offices in the first, second and third suggested area: ", [len(post_amount['features']) for post_amount in all_post])
# Out:
# Amount of kindergarten in the first, second and third suggested area:  [1, 3, 1]
# Amount of supermarket in the first, second and third suggested area:  [8, 1, 3]
# Amount of post offices in the first, second and third suggested area:  [7, 0, 0]

# %% [markdown]
# Okay the first location looks pretty good: There is a kindergarten, eight supermarket and seven post offices. It is the perfect location for our new home!

# %% [markdown]
# # geocoding

# %% [markdown]
# To get representable names the geocoding api is a useful solution.

# %%
name_markets = [(feat["properties"]['osm_tags']['name']) for feat in all_supermarket[0]['features']] # changing "Mollie Stone's" to "Mollie Stone"
name_markets[3] = 'Mollie Stone'
x = 0
for feat in all_supermarket[0]['features']:
    feat["properties"]['osm_tags']['name'] = name_markets[x]
    x = x+1
    
name_markets3 = [(feat["properties"]['osm_tags']['name']) for feat in all_supermarket[2]['features']] # changing "Mollie Stone's" to "Mollie Stone"
name_markets3[1] = 'Mollie Stone'
x = 0
for feat in all_supermarket[2]['features']:
    feat["properties"]['osm_tags']['name'] = name_markets3[x]
    x = x+1

# %%
all_places = {'all_kindergarten': all_kindergarten, 'all_supermarket': all_supermarket, 'all_post': all_post}

kindergarten_group = FeatureGroup(name='Kindergarten') 
supermarket_group = FeatureGroup(name='Supermarket')
post_group = FeatureGroup(name='Post Office')

for all_feat in all_places: # array mit allen locations und allen places
    all_features = all_places[all_feat]
    for group_feat in all_features: # array mit allen places
        single_feature = group_feat['features']
        for single_feat in single_feature:
            lon, lat = single_feat['geometry']['coordinates']
            if 'name' in single_feat['properties']:
                name = single_feat['properties']['osm_tags']['name']
            else:
                name = clnt.reverse_geocode(location=(lon, lat))['features'][0]['properties']['name']
                popup = "<strong>{0}</strong><br>Lat: {1:.3f}<br>Long: {2:.3f}".format(name, lat, lon)
            if '153' in single_feat['properties']['category_ids']:
                folium.map.Marker([lat, lon], icon=folium.Icon(color='lightgray', icon_color='#ffcc00', icon='child', prefix='fa'), popup=popup).add_to(kindergarten_group)
            elif '518' in single_feat['properties']['category_ids']:
                folium.map.Marker([lat, lon], icon=folium.Icon(color='lightgray', icon_color='#009900', icon='shopping-cart', prefix='fa'), popup=popup).add_to(supermarket_group)
            else:
                folium.map.Marker([lat, lon], icon=folium.Icon(color='lightgray', icon_color='#1a1aff', icon='envelope', prefix='fa'), popup=popup).add_to(post_group)

kindergarten_group.add_to(map1)
supermarket_group.add_to(map1)
post_group.add_to(map1)
                
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # directions

# %%
first_house_coords = [-122.430954, 37.792965]
first_area_direction = []
for all_feat in all_places: # array mit allen places für erste location
    first_features = all_places[all_feat][0]['features']
    for coords_first_features in first_features:
        first_area = [coords_first_features['geometry']['coordinates']]
        for coords in first_area:
            first_direction_request = directions(client=clnt, coordinates=(first_house_coords, coords), profile='foot-walking', format_out='geojson')
            folium.GeoJson(first_direction_request).add_to(kindergarten_group)
            first_area_direction.append(first_direction_request)

second_house_coords = [-122.501636, 37.748653]
for all_feat in all_places: # array mit allen places für erste location
    second_features = all_places[all_feat][1]['features']
    for coords_second_features in second_features:
        second_area = [coords_second_features['geometry']['coordinates']]
        for coords in second_area:
            second_direction_request = directions(client=clnt, coordinates=(second_house_coords, coords), profile='foot-walking', format_out='geojson')
            folium.GeoJson(second_direction_request).add_to(supermarket_group)
            
third_house_coords = [-122.446629, 37.736928]
for all_feat in all_places: # array mit allen places für erste location
    third_features = all_places[all_feat][2]['features']
    for coords_third_features in third_features:
        third_area = [coords_third_features['geometry']['coordinates']]
        for coords in third_area:
            third_direction_request = directions(client=clnt, coordinates=(third_house_coords, coords), profile='foot-walking', format_out='geojson')
            folium.GeoJson(third_direction_request).add_to(post_group)
        
map1.add_child(folium.map.LayerControl())   # funktioniert noch nicht         
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Recommended walking route

# %% [markdown]
# To save time we want to create the optimal route. First bring the children to the kindergarten and then do all the groceries before heading home again.

# %%
for wer in first_area_direction:
    eins = wer['features']
    for wer2 in eins:
        zwei = wer2['properties']['segments']
        for wer3 in zwei:
            pprint(wer3['duration'])
# Out:
# 928.2
# 1023.6
# 689.9
# 1054.8
# 605.3
# 802.8
# 886.7
# 812.6
# 682.7
# 683.1
# 805
# 1018.8
# 664
# 773.6
# 1016.4
# 949.1

# %%
for wer in first_area_direction:
   # eins = wer['features']
    pprint(wer)
# Out:
# {'bbox': [-122.430948, 37.782942, -122.427724, 37.793103],
#  'features': [{'geometry': {'coordinates': [[-122.430948, 37.792936],
#                                             [-122.42964, 37.793103],
#                                             [-122.429465, 37.792223],
#                                             [-122.429305, 37.79143],
#                                             [-122.429289, 37.791347],
#                                             [-122.429274, 37.791275],
#                                             [-122.429126, 37.790541],
#                                             [-122.429111, 37.790467],
#                                             [-122.429097, 37.790396],
#                                             [-122.428944, 37.789639],
#                                             [-122.428924, 37.789537],
#                                             [-122.428905, 37.789443],
#                                             [-122.428748, 37.788668],
#                                             [-122.428731, 37.788584],
#                                             [-122.428716, 37.788507],
#                                             [-122.42856, 37.787736],
#                                             [-122.428543, 37.787652],
#                                             [-122.428527, 37.787571],
#                                             [-122.428437, 37.787126],
#                                             [-122.428371, 37.7868],
#                                             [-122.428355, 37.786718],
#                                             [-122.42834, 37.786645],
#                                             [-122.428261, 37.786258],
#                                             [-122.428182, 37.78587],
#                                             [-122.428165, 37.785787],
#                                             [-122.428149, 37.785707],
#                                             [-122.428036, 37.785152],
#                                             [-122.428014, 37.785044],
#                                             [-122.427982, 37.784885],
#                                             [-122.42796, 37.784777],
#                                             [-122.427839, 37.784176],
#                                             [-122.427789, 37.783926],
#                                             [-122.427724, 37.783606],
#                                             [-122.428064, 37.783562],
#                                             [-122.428036, 37.783441],
#                                             [-122.427998, 37.783244],
#                                             [-122.42794, 37.782948],
#                                             [-122.427984, 37.782942]],
#                             'type': 'LineString'},
#                'id': 'fid-79c28dca_162cc0351d1_-7d43',
#                'properties': {'bbox': [-122.430948,
#                                        37.782942,
#                                        -122.427724,
#                                        37.793103],
#                               'highlight': {},
#                               'segments': [{'distance': 1289.1,
#                                             'duration': 928.2,
#                                             'steps': [{'distance': 116.5,
#                                                        'duration': 83.9,
#                                                        'instruction': 'Head '
#                                                                       'east on '
#                                                                       'Jackson '
#                                                                       'Street',
#                                                        'name': 'Jackson Street',
#                                                        'type': 11,
#                                                        'way_points': [0, 1]},
#                                                       {'distance': 1069.3,
#                                                        'duration': 769.9,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'Laguna '
#                                                                       'Street',
#                                                        'name': 'Laguna Street',
#                                                        'type': 1,
#                                                        'way_points': [1, 32]},
#                                                       {'distance': 30.3,
#                                                        'duration': 21.8,
#                                                        'instruction': 'Turn '
#                                                                       'right',
#                                                        'name': '',
#                                                        'type': 1,
#                                                        'way_points': [32, 33]},
#                                                       {'distance': 69.1,
#                                                        'duration': 49.8,
#                                                        'instruction': 'Turn '
#                                                                       'left',
#                                                        'name': '',
#                                                        'type': 0,
#                                                        'way_points': [33, 36]},
#                                                       {'distance': 3.9,
#                                                        'duration': 2.8,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'Ellis '
#                                                                       'Street',
#                                                        'name': 'Ellis Street',
#                                                        'type': 1,
#                                                        'way_points': [36, 37]},
#                                                       {'distance': 0,
#                                                        'duration': 0,
#                                                        'instruction': 'Arrive '
#                                                                       'at '
#                                                                       'Ellis '
#                                                                       'Street, '
#                                                                       'on the '
#                                                                       'left',
#                                                        'name': '',
#                                                        'type': 10,
#                                                        'way_points': [37,
#                                                                       37]}]}],
#                               'style': {},
#                               'summary': [{'distance': 1289.1,
#                                            'duration': 928.2}],
#                               'way_points': [0, 37]},
#                'type': 'Feature'}],
#  'info': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#           'engine': {'build_date': '2018-03-26T13:30:15Z', 'version': '4.5.0'},
#           'osm_file_md5_hash': '2334169eacb30828c11eaa79f6ec4af1',
#           'query': {'coordinates': [[-122.430954, 37.792965],
#                                     [-122.42795, 37.782774]],
#                     'elevation': False,
#                     'geometry': True,
#                     'geometry_format': 'geojson',
#                     'geometry_simplify': False,
#                     'instructions': True,
#                     'instructions_format': 'text',
#                     'language': 'en',
#                     'preference': 'fastest',
#                     'profile': 'foot-walking',
#                     'units': 'm'},
#           'service': 'routing',
#           'timestamp': 1524063534293},
#  'type': 'FeatureCollection'}
# {'bbox': [-122.431572, 37.783043, -122.429907, 37.792936],
#  'features': [{'geometry': {'coordinates': [[-122.430948, 37.792936],
#                                             [-122.431196, 37.792905],
#                                             [-122.431286, 37.792894],
#                                             [-122.431271, 37.792819],
#                                             [-122.431124, 37.792088],
#                                             [-122.431109, 37.792015],
#                                             [-122.431094, 37.791943],
#                                             [-122.430977, 37.79136],
#                                             [-122.430946, 37.791208],
#                                             [-122.430932, 37.791138],
#                                             [-122.430917, 37.791066],
#                                             [-122.430769, 37.790331],
#                                             [-122.430754, 37.790257],
#                                             [-122.430739, 37.790185],
#                                             [-122.430587, 37.789431],
#                                             [-122.430566, 37.789328],
#                                             [-122.430547, 37.789233],
#                                             [-122.43039, 37.788457],
#                                             [-122.430374, 37.788376],
#                                             [-122.430358, 37.788298],
#                                             [-122.430202, 37.787527],
#                                             [-122.430186, 37.787443],
#                                             [-122.43017, 37.787367],
#                                             [-122.430013, 37.786589],
#                                             [-122.429997, 37.786512],
#                                             [-122.429979, 37.786419],
#                                             [-122.430074, 37.786407],
#                                             [-122.429907, 37.785566],
#                                             [-122.429955, 37.78556],
#                                             [-122.430087, 37.785543],
#                                             [-122.430849, 37.785447],
#                                             [-122.431205, 37.785402],
#                                             [-122.431311, 37.785388],
#                                             [-122.431296, 37.785312],
#                                             [-122.431266, 37.785165],
#                                             [-122.431239, 37.785029],
#                                             [-122.431195, 37.784812],
#                                             [-122.431181, 37.784746],
#                                             [-122.431019, 37.78485],
#                                             [-122.430823, 37.784875],
#                                             [-122.430828, 37.784902],
#                                             [-122.431055, 37.784875],
#                                             [-122.43094, 37.784287],
#                                             [-122.430887, 37.784294],
#                                             [-122.43085, 37.784299],
#                                             [-122.430865, 37.784371],
#                                             [-122.430953, 37.78436],
#                                             [-122.430944, 37.784306],
#                                             [-122.43094, 37.784287],
#                                             [-122.431085, 37.78427],
#                                             [-122.430949, 37.783599],
#                                             [-122.430934, 37.783526],
#                                             [-122.431078, 37.783508],
#                                             [-122.431317, 37.783476],
#                                             [-122.431237, 37.783122],
#                                             [-122.431449, 37.783095],
#                                             [-122.431572, 37.78308],
#                                             [-122.431567, 37.783043]],
#                             'type': 'LineString'},
#                'id': 'fid-16f60142_162cca82515_-7d34',
#                'properties': {'bbox': [-122.431572,
#                                        37.783043,
#                                        -122.429907,
#                                        37.792936],
#                               'highlight': {},
#                               'segments': [{'distance': 1421.7,
#                                             'duration': 1023.6,
#                                             'steps': [{'distance': 30.1,
#                                                        'duration': 21.7,
#                                                        'instruction': 'Head '
#                                                                       'west on '
#                                                                       'Jackson '
#                                                                       'Street',
#                                                        'name': 'Jackson Street',
#                                                        'type': 11,
#                                                        'way_points': [0, 2]},
#                                                       {'distance': 729,
#                                                        'duration': 524.9,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Buchanan '
#                                                                       'Street',
#                                                        'name': 'Buchanan '
#                                                                'Street',
#                                                        'type': 0,
#                                                        'way_points': [2, 25]},
#                                                       {'distance': 103.1,
#                                                        'duration': 74.2,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'Buchanan '
#                                                                       'Street',
#                                                        'name': 'Buchanan '
#                                                                'Street',
#                                                        'type': 1,
#                                                        'way_points': [25, 27]},
#                                                       {'distance': 125,
#                                                        'duration': 90,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'Post '
#                                                                       'Street',
#                                                        'name': 'Post Street',
#                                                        'type': 1,
#                                                        'way_points': [27, 32]},
#                                                       {'distance': 72.3,
#                                                        'duration': 52.1,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Webster '
#                                                                       'Street',
#                                                        'name': 'Webster Street',
#                                                        'type': 0,
#                                                        'way_points': [32, 37]},
#                                                       {'distance': 170.3,
#                                                        'duration': 122.6,
#                                                        'instruction': 'Turn '
#                                                                       'sharp '
#                                                                       'left',
#                                                        'name': '',
#                                                        'type': 2,
#                                                        'way_points': [37, 49]},
#                                                       {'distance': 83.8,
#                                                        'duration': 60.3,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Webster '
#                                                                       'Street',
#                                                        'name': 'Webster Street',
#                                                        'type': 0,
#                                                        'way_points': [49, 51]},
#                                                       {'distance': 34.1,
#                                                        'duration': 24.5,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       "O'Farrell "
#                                                                       'Street',
#                                                        'name': "O'Farrell "
#                                                                'Street',
#                                                        'type': 1,
#                                                        'way_points': [51, 53]},
#                                                       {'distance': 40,
#                                                        'duration': 28.8,
#                                                        'instruction': 'Turn '
#                                                                       'left',
#                                                        'name': '',
#                                                        'type': 0,
#                                                        'way_points': [53, 54]},
#                                                       {'distance': 29.8,
#                                                        'duration': 21.5,
#                                                        'instruction': 'Turn '
#                                                                       'right',
#                                                        'name': '',
#                                                        'type': 1,
#                                                        'way_points': [54, 56]},
#                                                       {'distance': 4.2,
#                                                        'duration': 3,
#                                                        'instruction': 'Turn '
#                                                                       'left',
#                                                        'name': '',
#                                                        'type': 0,
#                                                        'way_points': [56, 57]},
#                                                       {'distance': 0,
#                                                        'duration': 0,
#                                                        'instruction': 'Arrive '
#                                                                       'at your '
#                                                                       'destination, '
#                                                                       'on the '
#                                                                       'left',
#                                                        'name': '',
#                                                        'type': 10,
#                                                        'way_points': [57,
#                                                                       57]}]}],
#                               'style': {},
#                               'summary': [{'distance': 1421.7,
#                                            'duration': 1023.6}],
#                               'way_points': [0, 57]},
#                'type': 'Feature'}],
#  'info': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#           'engine': {'build_date': '2018-03-26T14:41:01Z', 'version': '4.5.0'},
#           'osm_file_md5_hash': '2334169eacb30828c11eaa79f6ec4af1',
#           'query': {'coordinates': [[-122.430954, 37.792965],
#                                     [-122.431464, 37.782711]],
#                     'elevation': False,
#                     'geometry': True,
#                     'geometry_format': 'geojson',
#                     'geometry_simplify': False,
#                     'instructions': True,
#                     'instructions_format': 'text',
#                     'language': 'en',
#                     'preference': 'fastest',
#                     'profile': 'foot-walking',
#                     'units': 'm'},
#           'service': 'routing',
#           'timestamp': 1524063534321},
#  'type': 'FeatureCollection'}
# {'bbox': [-122.431286, 37.785339, -122.429907, 37.792936],
#  'features': [{'geometry': {'coordinates': [[-122.430948, 37.792936],
#                                             [-122.431196, 37.792905],
#                                             [-122.431286, 37.792894],
#                                             [-122.431271, 37.792819],
#                                             [-122.431124, 37.792088],
#                                             [-122.431109, 37.792015],
#                                             [-122.431094, 37.791943],
#                                             [-122.430977, 37.79136],
#                                             [-122.430946, 37.791208],
#                                             [-122.430932, 37.791138],
#                                             [-122.430917, 37.791066],
#                                             [-122.430769, 37.790331],
#                                             [-122.430754, 37.790257],
#                                             [-122.430739, 37.790185],
#                                             [-122.430587, 37.789431],
#                                             [-122.430566, 37.789328],
#                                             [-122.430547, 37.789233],
#                                             [-122.43039, 37.788457],
#                                             [-122.430374, 37.788376],
#                                             [-122.430358, 37.788298],
#                                             [-122.430202, 37.787527],
#                                             [-122.430186, 37.787443],
#                                             [-122.43017, 37.787367],
#                                             [-122.430013, 37.786589],
#                                             [-122.429997, 37.786512],
#                                             [-122.429979, 37.786419],
#                                             [-122.430074, 37.786407],
#                                             [-122.429907, 37.785566],
#                                             [-122.429955, 37.78556],
#                                             [-122.430087, 37.785543],
#                                             [-122.430849, 37.785447],
#                                             [-122.430827, 37.785339]],
#                             'type': 'LineString'},
#                'id': 'fid-79c28dca_162cc0351d1_-7d42',
#                'properties': {'bbox': [-122.431286,
#                                        37.785339,
#                                        -122.429907,
#                                        37.792936],
#                               'highlight': {},
#                               'segments': [{'distance': 958.3,
#                                             'duration': 689.9,
#                                             'steps': [{'distance': 30.1,
#                                                        'duration': 21.7,
#                                                        'instruction': 'Head '
#                                                                       'west on '
#                                                                       'Jackson '
#                                                                       'Street',
#                                                        'name': 'Jackson Street',
#                                                        'type': 11,
#                                                        'way_points': [0, 2]},
#                                                       {'distance': 729,
#                                                        'duration': 524.9,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Buchanan '
#                                                                       'Street',
#                                                        'name': 'Buchanan '
#                                                                'Street',
#                                                        'type': 0,
#                                                        'way_points': [2, 25]},
#                                                       {'distance': 103.1,
#                                                        'duration': 74.2,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'Buchanan '
#                                                                       'Street',
#                                                        'name': 'Buchanan '
#                                                                'Street',
#                                                        'type': 1,
#                                                        'way_points': [25, 27]},
#                                                       {'distance': 83.9,
#                                                        'duration': 60.4,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'Post '
#                                                                       'Street',
#                                                        'name': 'Post Street',
#                                                        'type': 1,
#                                                        'way_points': [27, 30]},
#                                                       {'distance': 12.1,
#                                                        'duration': 8.7,
#                                                        'instruction': 'Turn '
#                                                                       'left',
#                                                        'name': '',
#                                                        'type': 0,
#                                                        'way_points': [30, 31]},
#                                                       {'distance': 0,
#                                                        'duration': 0,
#                                                        'instruction': 'Arrive '
#                                                                       'at your '
#                                                                       'destination, '
#                                                                       'on the '
#                                                                       'right',
#                                                        'name': '',
#                                                        'type': 10,
#                                                        'way_points': [31,
#                                                                       31]}]}],
#                               'style': {},
#                               'summary': [{'distance': 958.3,
#                                            'duration': 689.9}],
#                               'way_points': [0, 31]},
#                'type': 'Feature'}],
#  'info': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#           'engine': {'build_date': '2018-03-26T13:30:15Z', 'version': '4.5.0'},
#           'osm_file_md5_hash': '2334169eacb30828c11eaa79f6ec4af1',
#           'query': {'coordinates': [[-122.430954, 37.792965],
#                                     [-122.430902, 37.785201]],
#                     'elevation': False,
#                     'geometry': True,
#                     'geometry_format': 'geojson',
#                     'geometry_simplify': False,
#                     'instructions': True,
#                     'instructions_format': 'text',
#                     'language': 'en',
#                     'preference': 'fastest',
#                     'profile': 'foot-walking',
#                     'units': 'm'},
#           'service': 'routing',
#           'timestamp': 1524063534348},
#  'type': 'FeatureCollection'}
# {'bbox': [-122.43292, 37.792936, -122.42964, 37.804249],
#  'features': [{'geometry': {'coordinates': [[-122.430948, 37.792936],
#                                             [-122.42964, 37.793103],
#                                             [-122.429807, 37.793913],
#                                             [-122.42982, 37.793982],
#                                             [-122.429836, 37.794057],
#                                             [-122.429987, 37.79481],
#                                             [-122.430007, 37.794907],
#                                             [-122.430027, 37.795005],
#                                             [-122.430184, 37.795785],
#                                             [-122.430199, 37.795856],
#                                             [-122.430214, 37.795933],
#                                             [-122.430372, 37.796717],
#                                             [-122.430387, 37.796789],
#                                             [-122.430402, 37.796865],
#                                             [-122.43056, 37.797647],
#                                             [-122.430575, 37.797722],
#                                             [-122.430591, 37.7978],
#                                             [-122.430763, 37.798655],
#                                             [-122.430837, 37.799019],
#                                             [-122.430951, 37.799588],
#                                             [-122.431106, 37.800356],
#                                             [-122.431122, 37.80043],
#                                             [-122.431141, 37.800524],
#                                             [-122.431156, 37.8006],
#                                             [-122.43121, 37.800866],
#                                             [-122.431234, 37.800984],
#                                             [-122.431313, 37.801376],
#                                             [-122.431327, 37.801447],
#                                             [-122.431344, 37.80153],
#                                             [-122.431458, 37.802091],
#                                             [-122.431501, 37.80231],
#                                             [-122.431516, 37.802385],
#                                             [-122.431531, 37.802457],
#                                             [-122.431666, 37.80312],
#                                             [-122.431697, 37.803272],
#                                             [-122.431713, 37.803313],
#                                             [-122.431732, 37.803353],
#                                             [-122.431747, 37.803396],
#                                             [-122.431745, 37.803432],
#                                             [-122.431737, 37.803462],
#                                             [-122.431726, 37.803502],
#                                             [-122.431789, 37.803818],
#                                             [-122.431876, 37.804249],
#                                             [-122.431987, 37.804235],
#                                             [-122.43292, 37.804116]],
#                             'type': 'LineString'},
#                'id': 'fid-16f60142_162cca82515_-7d33',
#                'properties': {'bbox': [-122.43292,
#                                        37.792936,
#                                        -122.42964,
#                                        37.804249],
#                               'highlight': {},
#                               'segments': [{'distance': 1465.1,
#                                             'duration': 1054.8,
#                                             'steps': [{'distance': 116.5,
#                                                        'duration': 83.9,
#                                                        'instruction': 'Head '
#                                                                       'east on '
#                                                                       'Jackson '
#                                                                       'Street',
#                                                        'name': 'Jackson Street',
#                                                        'type': 11,
#                                                        'way_points': [0, 1]},
#                                                       {'distance': 1255.7,
#                                                        'duration': 904.1,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Laguna '
#                                                                       'Street',
#                                                        'name': 'Laguna Street',
#                                                        'type': 0,
#                                                        'way_points': [1, 42]},
#                                                       {'distance': 92.9,
#                                                        'duration': 66.9,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'North '
#                                                                       'Point '
#                                                                       'Street',
#                                                        'name': 'North Point '
#                                                                'Street',
#                                                        'type': 0,
#                                                        'way_points': [42, 44]},
#                                                       {'distance': 0,
#                                                        'duration': 0,
#                                                        'instruction': 'Arrive '
#                                                                       'at '
#                                                                       'North '
#                                                                       'Point '
#                                                                       'Street, '
#                                                                       'on the '
#                                                                       'right',
#                                                        'name': '',
#                                                        'type': 10,
#                                                        'way_points': [44,
#                                                                       44]}]}],
#                               'style': {},
#                               'summary': [{'distance': 1465.1,
#                                            'duration': 1054.8}],
#                               'way_points': [0, 44]},
#                'type': 'Feature'}],
#  'info': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#           'engine': {'build_date': '2018-03-26T14:41:01Z', 'version': '4.5.0'},
#           'osm_file_md5_hash': '2334169eacb30828c11eaa79f6ec4af1',
#           'query': {'coordinates': [[-122.430954, 37.792965],
#                                     [-122.432969, 37.804356]],
#                     'elevation': False,
#                     'geometry': True,
#                     'geometry_format': 'geojson',
#                     'geometry_simplify': False,
#                     'instructions': True,
#                     'instructions_format': 'text',
#                     'language': 'en',
#                     'preference': 'fastest',
#                     'profile': 'foot-walking',
#                     'units': 'm'},
#           'service': 'routing',
#           'timestamp': 1524063534373},
#  'type': 'FeatureCollection'}
# {'bbox': [-122.434822, 37.788509, -122.430932, 37.792936],
#  'features': [{'geometry': {'coordinates': [[-122.430948, 37.792936],
#                                             [-122.431196, 37.792905],
#                                             [-122.431286, 37.792894],
#                                             [-122.431271, 37.792819],
#                                             [-122.431124, 37.792088],
#                                             [-122.431109, 37.792015],
#                                             [-122.431094, 37.791943],
#                                             [-122.430977, 37.79136],
#                                             [-122.430946, 37.791208],
#                                             [-122.430932, 37.791138],
#                                             [-122.431564, 37.791058],
#                                             [-122.431671, 37.791044],
#                                             [-122.432411, 37.79095],
#                                             [-122.432581, 37.790928],
#                                             [-122.432669, 37.790917],
#                                             [-122.433778, 37.790776],
#                                             [-122.43361, 37.789893],
#                                             [-122.433643, 37.789889],
#                                             [-122.433949, 37.78985],
#                                             [-122.434043, 37.789838],
#                                             [-122.434029, 37.789768],
#                                             [-122.433877, 37.789012],
#                                             [-122.433857, 37.788909],
#                                             [-122.43395, 37.788897],
#                                             [-122.434787, 37.788791],
#                                             [-122.434822, 37.788787],
#                                             [-122.434805, 37.788692],
#                                             [-122.434788, 37.788603],
#                                             [-122.434771, 37.788509]],
#                             'type': 'LineString'},
#                'id': 'fid-79c28dca_162cc0351d1_-7d41',
#                'properties': {'bbox': [-122.434822,
#                                        37.788509,
#                                        -122.430932,
#                                        37.792936],
#                               'highlight': {},
#                               'segments': [{'distance': 840.7,
#                                             'duration': 605.3,
#                                             'steps': [{'distance': 30.1,
#                                                        'duration': 21.7,
#                                                        'instruction': 'Head '
#                                                                       'west on '
#                                                                       'Jackson '
#                                                                       'Street',
#                                                        'name': 'Jackson Street',
#                                                        'type': 11,
#                                                        'way_points': [0, 2]},
#                                                       {'distance': 197.7,
#                                                        'duration': 142.3,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Buchanan '
#                                                                       'Street',
#                                                        'name': 'Buchanan '
#                                                                'Street',
#                                                        'type': 0,
#                                                        'way_points': [2, 9]},
#                                                       {'distance': 56.2,
#                                                        'duration': 40.5,
#                                                        'instruction': 'Turn '
#                                                                       'right',
#                                                        'name': '',
#                                                        'type': 1,
#                                                        'way_points': [9, 10]},
#                                                       {'distance': 197.1,
#                                                        'duration': 141.9,
#                                                        'instruction': 'Continue '
#                                                                       'straight '
#                                                                       'onto '
#                                                                       'Clay '
#                                                                       'Street',
#                                                        'name': 'Clay Street',
#                                                        'type': 6,
#                                                        'way_points': [10, 15]},
#                                                       {'distance': 99.3,
#                                                        'duration': 71.5,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Goldberg '
#                                                                       'Lane',
#                                                        'name': 'Goldberg Lane',
#                                                        'type': 0,
#                                                        'way_points': [15, 16]},
#                                                       {'distance': 38.5,
#                                                        'duration': 27.7,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'Sacramento '
#                                                                       'Street',
#                                                        'name': 'Sacramento '
#                                                                'Street',
#                                                        'type': 1,
#                                                        'way_points': [16, 19]},
#                                                       {'distance': 104.5,
#                                                        'duration': 75.3,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Fillmore '
#                                                                       'Street',
#                                                        'name': 'Fillmore '
#                                                                'Street',
#                                                        'type': 0,
#                                                        'way_points': [19, 22]},
#                                                       {'distance': 85.9,
#                                                        'duration': 61.9,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'California '
#                                                                       'Street',
#                                                        'name': 'California '
#                                                                'Street',
#                                                        'type': 1,
#                                                        'way_points': [22, 25]},
# ...
#                                                                       'right',
#                                                        'name': '',
#                                                        'type': 1,
#                                                        'way_points': [12, 13]},
#                                                       {'distance': 49.3,
#                                                        'duration': 35.5,
#                                                        'instruction': 'Turn '
#                                                                       'left',
#                                                        'name': '',
#                                                        'type': 0,
#                                                        'way_points': [13, 14]},
#                                                       {'distance': 80.2,
#                                                        'duration': 57.8,
#                                                        'instruction': 'Turn '
#                                                                       'right',
#                                                        'name': '',
#                                                        'type': 1,
#                                                        'way_points': [14, 19]},
#                                                       {'distance': 19.7,
#                                                        'duration': 14.2,
#                                                        'instruction': 'Turn '
#                                                                       'slight '
#                                                                       'right',
#                                                        'name': '',
#                                                        'type': 5,
#                                                        'way_points': [19, 21]},
#                                                       {'distance': 7.9,
#                                                        'duration': 5.7,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Sacramento '
#                                                                       'Street',
#                                                        'name': 'Sacramento '
#                                                                'Street',
#                                                        'type': 0,
#                                                        'way_points': [21, 22]},
#                                                       {'distance': 212,
#                                                        'duration': 152.7,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'Octavia '
#                                                                       'Street',
#                                                        'name': 'Octavia Street',
#                                                        'type': 1,
#                                                        'way_points': [22, 28]},
#                                                       {'distance': 697,
#                                                        'duration': 501.8,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Pine '
#                                                                       'Street',
#                                                        'name': 'Pine Street',
#                                                        'type': 0,
#                                                        'way_points': [28, 44]},
#                                                       {'distance': 0,
#                                                        'duration': 0,
#                                                        'instruction': 'Arrive '
#                                                                       'at Pine '
#                                                                       'Street, '
#                                                                       'on the '
#                                                                       'left',
#                                                        'name': '',
#                                                        'type': 10,
#                                                        'way_points': [44,
#                                                                       44]}]}],
#                               'style': {},
#                               'summary': [{'distance': 1411.7,
#                                            'duration': 1016.4}],
#                               'way_points': [0, 44]},
#                'type': 'Feature'}],
#  'info': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#           'engine': {'build_date': '2018-03-26T13:30:15Z', 'version': '4.5.0'},
#           'osm_file_md5_hash': '2334169eacb30828c11eaa79f6ec4af1',
#           'query': {'coordinates': [[-122.430954, 37.792965],
#                                     [-122.419275, 37.789877]],
#                     'elevation': False,
#                     'geometry': True,
#                     'geometry_format': 'geojson',
#                     'geometry_simplify': False,
#                     'instructions': True,
#                     'instructions_format': 'text',
#                     'language': 'en',
#                     'preference': 'fastest',
#                     'profile': 'foot-walking',
#                     'units': 'm'},
#           'service': 'routing',
#           'timestamp': 1524063534675},
#  'type': 'FeatureCollection'}
# {'bbox': [-122.43362, 37.784114, -122.429997, 37.792936],
#  'features': [{'geometry': {'coordinates': [[-122.430948, 37.792936],
#                                             [-122.431196, 37.792905],
#                                             [-122.431286, 37.792894],
#                                             [-122.431271, 37.792819],
#                                             [-122.431124, 37.792088],
#                                             [-122.431109, 37.792015],
#                                             [-122.431094, 37.791943],
#                                             [-122.430977, 37.79136],
#                                             [-122.430946, 37.791208],
#                                             [-122.430932, 37.791138],
#                                             [-122.430917, 37.791066],
#                                             [-122.430769, 37.790331],
#                                             [-122.430754, 37.790257],
#                                             [-122.430739, 37.790185],
#                                             [-122.430587, 37.789431],
#                                             [-122.430566, 37.789328],
#                                             [-122.430547, 37.789233],
#                                             [-122.43039, 37.788457],
#                                             [-122.430374, 37.788376],
#                                             [-122.430358, 37.788298],
#                                             [-122.430202, 37.787527],
#                                             [-122.430186, 37.787443],
#                                             [-122.43017, 37.787367],
#                                             [-122.430013, 37.786589],
#                                             [-122.429997, 37.786512],
#                                             [-122.430095, 37.786499],
#                                             [-122.431391, 37.786335],
#                                             [-122.4315, 37.786321],
#                                             [-122.431643, 37.786303],
#                                             [-122.431747, 37.78629],
#                                             [-122.432215, 37.786231],
#                                             [-122.432336, 37.786215],
#                                             [-122.433194, 37.786107],
#                                             [-122.433288, 37.786095],
#                                             [-122.433272, 37.786016],
#                                             [-122.433215, 37.785737],
#                                             [-122.433115, 37.785247],
#                                             [-122.433097, 37.785162],
#                                             [-122.43308, 37.785076],
#                                             [-122.43305, 37.784929],
#                                             [-122.43298, 37.784587],
#                                             [-122.432967, 37.784523],
#                                             [-122.432904, 37.784205],
#                                             [-122.433005, 37.784192],
#                                             [-122.43362, 37.784114]],
#                             'type': 'LineString'},
#                'id': 'fid-16f60142_162cca82515_-7d2d',
#                'properties': {'bbox': [-122.43362,
#                                        37.784114,
#                                        -122.429997,
#                                        37.792936],
#                               'highlight': {},
#                               'segments': [{'distance': 1318.2,
#                                             'duration': 949.1,
#                                             'steps': [{'distance': 30.1,
#                                                        'duration': 21.7,
#                                                        'instruction': 'Head '
#                                                                       'west on '
#                                                                       'Jackson '
#                                                                       'Street',
#                                                        'name': 'Jackson Street',
#                                                        'type': 11,
#                                                        'way_points': [0, 2]},
#                                                       {'distance': 718.6,
#                                                        'duration': 517.4,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Buchanan '
#                                                                       'Street',
#                                                        'name': 'Buchanan '
#                                                                'Street',
#                                                        'type': 0,
#                                                        'way_points': [2, 24]},
#                                                       {'distance': 292.9,
#                                                        'duration': 210.9,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'Sutter '
#                                                                       'Street',
#                                                        'name': 'Sutter Street',
#                                                        'type': 1,
#                                                        'way_points': [24, 33]},
#                                                       {'distance': 212.8,
#                                                        'duration': 153.2,
#                                                        'instruction': 'Turn '
#                                                                       'left '
#                                                                       'onto '
#                                                                       'Fillmore '
#                                                                       'Street',
#                                                        'name': 'Fillmore '
#                                                                'Street',
#                                                        'type': 0,
#                                                        'way_points': [33, 42]},
#                                                       {'distance': 63.8,
#                                                        'duration': 45.9,
#                                                        'instruction': 'Turn '
#                                                                       'right '
#                                                                       'onto '
#                                                                       'Geary '
#                                                                       'Boulevard',
#                                                        'name': 'Geary '
#                                                                'Boulevard',
#                                                        'type': 1,
#                                                        'way_points': [42, 44]},
#                                                       {'distance': 0,
#                                                        'duration': 0,
#                                                        'instruction': 'Arrive '
#                                                                       'at '
#                                                                       'Geary '
#                                                                       'Boulevard, '
#                                                                       'on the '
#                                                                       'left',
#                                                        'name': '',
#                                                        'type': 10,
#                                                        'way_points': [44,
#                                                                       44]}]}],
#                               'style': {},
#                               'summary': [{'distance': 1318.2,
#                                            'duration': 949.1}],
#                               'way_points': [0, 44]},
#                'type': 'Feature'}],
#  'info': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#           'engine': {'build_date': '2018-03-26T14:41:01Z', 'version': '4.5.0'},
#           'osm_file_md5_hash': '2334169eacb30828c11eaa79f6ec4af1',
#           'query': {'coordinates': [[-122.430954, 37.792965],
#                                     [-122.433584, 37.783935]],
#                     'elevation': False,
#                     'geometry': True,
#                     'geometry_format': 'geojson',
#                     'geometry_simplify': False,
#                     'instructions': True,
#                     'instructions_format': 'text',
#                     'language': 'en',
#                     'preference': 'fastest',
#                     'profile': 'foot-walking',
#                     'units': 'm'},
#           'service': 'routing',
#           'timestamp': 1524063534701},
#  'type': 'FeatureCollection'}

# %%
route_array = [] # create list with the needed elemets for the perfect route
route_array1.append({'geometry': {'coordinates': SF1_switched}}) 
route_array1.append(kindergarten1[0])
route_array1.append(supermarket1[2]) 
route_array1.append(post1[6]) 
route_array1.append({'geometry': {'coordinates': SF1_switched}}) 

route_array.append(first_house_coords, )

# %%
route_direct1 = {'coordinates': [(wer['geometry']['coordinates']) for wer in route_array1],
                  'profile': 'foot-walking',
                  'preference': 'shortest',
                  'geometry': 'true',
                  'format_out': 'geojson'
                 }

all_route1 = clnt.directions(**route_direct1) # request of directions

for alle in all_route1['features']:
    all_route = alle['geometry']['coordinates']
    
all_route =[[y,x] for x,y in all_route]

folium.PolyLine(all_route, color="#c6538c").add_to(route_group) # saving it up in the route feature group

route_group.add_to(map1)

# %% [markdown]
# Now we have the four feature groups with all the data saved up. Using now the Layer Control we can switch on and off the different sites and routes.

# %% [markdown]
# For completion we will calculate the total duration for the Optimal Route. We already received the duration with the direction module and saved it up in 'all_route1'.

# %%
routedur1 = [(alle['properties']['segments']) for alle in all_route1['features']]
routedur2 = [(wer['duration']) for wer in routedur1[0]] 
routedur2 # duration from site to site # home - kindergarten - post office - supermarket - home
# Out:
# [928.2, 431.1, 10.6, 683.1]

# %%
sum = 0 # sum of all single durations
for num in routedur2:
    sum += num
sum # duration in seconds
# Out:
# 2053.0

# %%
summe = sum / 60 # dividing by 60 to get the duration in minutes
print("Duration for Optimal Route: {:.2f} minutes.".format(summe))
# Out:
# Duration for Optimal Route: 34.22 minutes.
